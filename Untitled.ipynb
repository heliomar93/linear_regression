# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)
diamonds.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.21    Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 1   0.23       Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 2   0.29    Premium     I     VS2   62.4   58.0  334.0  4.20  4.23  2.63
# 3   0.31       Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75
# 4   0.24  Very Good     J    VVS2   62.8   57.0  336.0  3.94  3.96  2.48
#
#    clarity_  color_
# 0         2       5
# 1         4       5
# 2         3       1
# 3         1       0
# 4         5       0

# %%
d1=diamonds.loc[diamonds["clarity_"]==4,]

# %%
plt.figure(figsize=(20, 20))
p = sns.heatmap(d1.corr(), annot=True, square=True)

# %%
rick=pd.read_csv("rick_diamonds.csv")

# %%
rick.describe()
# Out:
#              carat        depth        table            x            y  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.799144    61.724680    57.516140     5.735516     5.736410
# std       0.472936     1.457691     2.244019     1.120300     1.110345
# min       0.200000    44.000000    50.000000     0.000000     0.000000
# 25%       0.400000    61.000000    56.000000     4.720000     4.720000
# 50%       0.710000    61.800000    57.000000     5.710000     5.720000
# 75%       1.040000    62.500000    59.000000     6.530000     6.520000
# max       4.130000    73.600000    70.000000    10.000000     9.850000
#
#                  z
# count  5000.000000
# mean      3.539576
# std       0.694733
# min       0.000000
# 25%       2.910000
# 50%       3.530000
# 75%       4.032500
# max       6.430000

# %%
X=np.log(diamonds[['cut_','carat',"clarity_","color_"]])
yobs=np.log(diamonds['price'])
model=LinearRegression()
model.fit(X,yobs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-4776796761ef> in <module>
# ----> 1 X=np.log(diamonds[['cut_','carat',"clarity_","color_"]])
#       2 yobs=np.log(diamonds['price'])
#       3 model=LinearRegression()
#       4 model.fit(X,yobs)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
rick["price_predicted"]=np.exp(model.predict(np.log(rick[["cut_",'carat',"clarity_","color_"]])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e8ed87e5bfd4> in <module>
# ----> 1 rick["price_predicted"]=np.exp(model.predict(np.log(rick[["cut_",'carat',"clarity_","color_"]])))
#
# NameError: name 'model' is not defined
